# %% [markdown]
# ### LOCALISER LES FICHIERS

# %%
from pathlib import Path

import pandas as pd

# le chemins actuelle 
ROOT = Path.cwd()
#print(ROOT)
ROOT= ROOT.parent
RAW_DIR = ROOT / "data" / "raw"
# cherche tous les fichiers CSV dans data/raw
csv_files = list(RAW_DIR.glob("*.csv"))

print(f"Racine du projet : {ROOT}")
print(f"Nombre de fichiers CSV : {len(csv_files)}")

for file in csv_files:
    print(file.name)
# Out:
# Racine du projet : /home/kachair/ecommerce-bi-platform
# Nombre de fichiers CSV : 9
# olist_order_reviews_dataset.csv
# olist_products_dataset.csv
# olist_order_items_dataset.csv
# olist_orders_dataset.csv
# olist_customers_dataset.csv
# product_category_name_translation.csv
# olist_sellers_dataset.csv
# olist_order_payments_dataset.csv
# olist_geolocation_dataset.csv
